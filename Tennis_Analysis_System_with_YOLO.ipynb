# %% [markdown]
# <a href="https://colab.research.google.com/github/PythonDecorator/Computer-Vision-Apps/blob/master/Tennis_Analysis_System_with_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Install pakages

# %%
# !pip install -q ultralytics
# !pip install -q lap

# %% [markdown]
# # Imports

# %%
import os
import pickle
import numpy as np

# traking and object detection
from ultralytics import YOLO
import lap
import cv2

# courtline detection
import torch
import torchvision.transforms as transforms
from torchvision import models

# Display Video and other results
from IPython.display import HTML
from base64 import b64encode

# %%
# mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
INPUT_VIDEO_PATH = "/content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4"
YOLO_MODEL = "yolo12n.pt"

# %% [markdown]
# # Perform Object Detection/Tracking - using YOLO

# %%
#Load the YOLOv12 Model
model = YOLO(YOLO_MODEL)

#Predictions
results = model.track(source=INPUT_VIDEO_PATH, save=True, persist=True, stream=True)

# %%
for frame_idx, r in enumerate(results):
    frame = r.orig_img  # numpy array (H, W, 3) BGR
    boxes = r.boxes

    if boxes is None or boxes.xyxy is None or len(boxes) == 0:
        continue

    xyxy = boxes.xyxy.cpu().numpy()  # (N, 4)
    ids = None
    if boxes.id is not None:
        ids = boxes.id.cpu().numpy().astype(int)  # (N,)
# Out:
# video 1/1 (frame 1/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 366.8ms
# video 1/1 (frame 2/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 147.8ms
# video 1/1 (frame 3/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 142.7ms
# video 1/1 (frame 4/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 136.3ms
# video 1/1 (frame 5/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 150.8ms
# video 1/1 (frame 6/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 138.4ms
# video 1/1 (frame 7/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 137.8ms
# video 1/1 (frame 8/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 140.0ms
# video 1/1 (frame 9/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 139.0ms
# video 1/1 (frame 10/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 168.1ms
# video 1/1 (frame 11/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 285.9ms
# video 1/1 (frame 12/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 149.1ms
# video 1/1 (frame 13/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 148.0ms
# video 1/1 (frame 14/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 134.3ms
# video 1/1 (frame 15/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 137.5ms
# video 1/1 (frame 16/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 144.9ms
# video 1/1 (frame 17/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 131.0ms
# video 1/1 (frame 18/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 148.2ms
# video 1/1 (frame 19/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 210.9ms
# video 1/1 (frame 20/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 202.3ms
# video 1/1 (frame 21/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 206.6ms
# video 1/1 (frame 22/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 204.1ms
# video 1/1 (frame 23/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 196.8ms
# video 1/1 (frame 24/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 5 persons, 1 tennis racket, 200.0ms
# video 1/1 (frame 25/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 1 tennis racket, 214.5ms
# video 1/1 (frame 26/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 1 tennis racket, 206.6ms
# video 1/1 (frame 27/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 1 tennis racket, 214.2ms
# video 1/1 (frame 28/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 1 tennis racket, 234.2ms
# video 1/1 (frame 29/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 2 tennis rackets, 208.8ms
# video 1/1 (frame 30/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 1 tennis racket, 217.2ms
# video 1/1 (frame 31/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 2 tennis rackets, 139.2ms
# video 1/1 (frame 32/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 2 tennis rackets, 146.1ms
# video 1/1 (frame 33/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 1 tennis racket, 142.1ms
# video 1/1 (frame 34/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 2 tennis rackets, 135.6ms
# video 1/1 (frame 35/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 2 tennis rackets, 131.6ms
# video 1/1 (frame 36/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 1 tennis racket, 155.0ms
# video 1/1 (frame 37/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 142.0ms
# video 1/1 (frame 38/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 137.3ms
# video 1/1 (frame 39/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 137.0ms
# video 1/1 (frame 40/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 134.7ms
# video 1/1 (frame 41/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 158.6ms
# video 1/1 (frame 42/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 144.3ms
# video 1/1 (frame 43/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 139.3ms
# video 1/1 (frame 44/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 139.5ms
# video 1/1 (frame 45/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 139.8ms
# video 1/1 (frame 46/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 151.5ms
# video 1/1 (frame 47/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 139.9ms
# video 1/1 (frame 48/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 137.3ms
# video 1/1 (frame 49/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 137.0ms
# video 1/1 (frame 50/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 137.3ms
# video 1/1 (frame 51/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 147.7ms
# video 1/1 (frame 52/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 135.9ms
# video 1/1 (frame 53/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 132.6ms
# video 1/1 (frame 54/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 150.8ms
# video 1/1 (frame 55/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 159.5ms
# video 1/1 (frame 56/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 130.2ms
# video 1/1 (frame 57/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 143.1ms
# video 1/1 (frame 58/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 134.0ms
# video 1/1 (frame 59/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 137.8ms
# video 1/1 (frame 60/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 163.0ms
# video 1/1 (frame 61/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 136.8ms
# video 1/1 (frame 62/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 131.8ms
# video 1/1 (frame 63/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 135.7ms
# video 1/1 (frame 64/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 138.3ms
# video 1/1 (frame 65/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 148.0ms
# video 1/1 (frame 66/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 136.5ms
# video 1/1 (frame 67/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 133.5ms
# video 1/1 (frame 68/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 139.5ms
# video 1/1 (frame 69/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 153.2ms
# video 1/1 (frame 70/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 154.4ms
# video 1/1 (frame 71/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 135.8ms
# video 1/1 (frame 72/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 137.3ms
# video 1/1 (frame 73/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 136.1ms
# video 1/1 (frame 74/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 149.1ms
# video 1/1 (frame 75/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 137.9ms
# video 1/1 (frame 76/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 165.2ms
# video 1/1 (frame 77/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 204.6ms
# video 1/1 (frame 78/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 206.1ms
# video 1/1 (frame 79/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 211.7ms
# video 1/1 (frame 80/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 202.5ms
# video 1/1 (frame 81/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 197.2ms
# video 1/1 (frame 82/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 199.1ms
# video 1/1 (frame 83/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 213.3ms
# video 1/1 (frame 84/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 196.9ms
# video 1/1 (frame 85/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 212.3ms
# video 1/1 (frame 86/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 211.7ms
# video 1/1 (frame 87/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 219.1ms
# video 1/1 (frame 88/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 228.7ms
# video 1/1 (frame 89/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 188.9ms
# video 1/1 (frame 90/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 143.6ms
# video 1/1 (frame 91/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 140.2ms
# video 1/1 (frame 92/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 140.2ms
# video 1/1 (frame 93/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 140.2ms
# video 1/1 (frame 94/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 139.1ms
# video 1/1 (frame 95/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 153.1ms
# video 1/1 (frame 96/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 133.2ms
# video 1/1 (frame 97/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 159.4ms
# video 1/1 (frame 98/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 141.2ms
# video 1/1 (frame 99/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 138.9ms
# video 1/1 (frame 100/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 159.7ms
# video 1/1 (frame 101/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 136.0ms
# video 1/1 (frame 102/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 151.5ms
# video 1/1 (frame 103/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 145.1ms
# video 1/1 (frame 104/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 145.3ms
# video 1/1 (frame 105/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 413.1ms
# video 1/1 (frame 106/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 144.9ms
# video 1/1 (frame 107/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 140.1ms
# video 1/1 (frame 108/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 143.8ms
# video 1/1 (frame 109/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 147.5ms
# video 1/1 (frame 110/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 156.5ms
# video 1/1 (frame 111/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 147.6ms
# video 1/1 (frame 112/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 137.6ms
# video 1/1 (frame 113/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 141.0ms
# video 1/1 (frame 114/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 138.9ms
# video 1/1 (frame 115/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 148.0ms
# video 1/1 (frame 116/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 138.7ms
# video 1/1 (frame 117/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 139.5ms
# video 1/1 (frame 118/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 135.5ms
# video 1/1 (frame 119/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 158.2ms
# video 1/1 (frame 120/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 141.6ms
# video 1/1 (frame 121/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 140.8ms
# video 1/1 (frame 122/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 135.0ms
# video 1/1 (frame 123/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 135.7ms
# video 1/1 (frame 124/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 179.9ms
# video 1/1 (frame 125/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 141.8ms
# video 1/1 (frame 126/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 138.1ms
# video 1/1 (frame 127/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 140.0ms
# video 1/1 (frame 128/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 144.1ms
# video 1/1 (frame 129/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 148.9ms
# video 1/1 (frame 130/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 152.9ms
# video 1/1 (frame 131/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 138.0ms
# video 1/1 (frame 132/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 148.1ms
# video 1/1 (frame 133/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 241.3ms
# video 1/1 (frame 134/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 212.3ms
# video 1/1 (frame 135/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 227.3ms
# video 1/1 (frame 136/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 237.3ms
# video 1/1 (frame 137/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 227.4ms
# video 1/1 (frame 138/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 211.4ms
# video 1/1 (frame 139/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 237.7ms
# video 1/1 (frame 140/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 223.6ms
# video 1/1 (frame 141/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 230.2ms
# video 1/1 (frame 142/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 217.6ms
# video 1/1 (frame 143/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 214.1ms
# video 1/1 (frame 144/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 220.3ms
# video 1/1 (frame 145/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 168.9ms
# video 1/1 (frame 146/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 142.8ms
# video 1/1 (frame 147/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 150.2ms
# video 1/1 (frame 148/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 148.2ms
# video 1/1 (frame 149/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 142.0ms
# video 1/1 (frame 150/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 153.4ms
# video 1/1 (frame 151/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 142.0ms
# video 1/1 (frame 152/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 143.2ms
# video 1/1 (frame 153/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 154.1ms
# video 1/1 (frame 154/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 145.3ms
# video 1/1 (frame 155/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 146.8ms
# video 1/1 (frame 156/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 139.4ms
# video 1/1 (frame 157/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 143.6ms
# video 1/1 (frame 158/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 146.7ms
# video 1/1 (frame 159/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 160.5ms
# video 1/1 (frame 160/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 136.9ms
# video 1/1 (frame 161/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 140.7ms
# video 1/1 (frame 162/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 149.0ms
# video 1/1 (frame 163/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 139.1ms
# video 1/1 (frame 164/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 151.0ms
# video 1/1 (frame 165/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 142.8ms
# video 1/1 (frame 166/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 141.0ms
# video 1/1 (frame 167/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 140.8ms
# video 1/1 (frame 168/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 138.5ms
# video 1/1 (frame 169/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 140.0ms
# video 1/1 (frame 170/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 140.4ms
# video 1/1 (frame 171/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 141.5ms
# video 1/1 (frame 172/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 139.0ms
# video 1/1 (frame 173/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 148.9ms
# video 1/1 (frame 174/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 179.6ms
# video 1/1 (frame 175/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 196.7ms
# video 1/1 (frame 176/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 143.7ms
# video 1/1 (frame 177/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 336.1ms
# video 1/1 (frame 178/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 137.9ms
# video 1/1 (frame 179/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 139.8ms
# video 1/1 (frame 180/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 400.0ms
# video 1/1 (frame 181/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 161.8ms
# video 1/1 (frame 182/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 147.4ms
# video 1/1 (frame 183/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 133.0ms
# video 1/1 (frame 184/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 150.5ms
# video 1/1 (frame 185/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 138.1ms
# video 1/1 (frame 186/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 135.8ms
# video 1/1 (frame 187/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 206.0ms
# video 1/1 (frame 188/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 223.3ms
# video 1/1 (frame 189/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 206.1ms
# video 1/1 (frame 190/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 203.0ms
# video 1/1 (frame 191/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 231.3ms
# video 1/1 (frame 192/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 211.7ms
# video 1/1 (frame 193/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 200.3ms
# video 1/1 (frame 194/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 207.1ms
# video 1/1 (frame 195/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 213.2ms
# video 1/1 (frame 196/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 211.3ms
# video 1/1 (frame 197/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 219.0ms
# video 1/1 (frame 198/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 221.9ms
# video 1/1 (frame 199/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 144.4ms
# video 1/1 (frame 200/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 132.2ms
# video 1/1 (frame 201/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 134.8ms
# video 1/1 (frame 202/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 168.6ms
# video 1/1 (frame 203/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 161.7ms
# video 1/1 (frame 204/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 140.1ms
# video 1/1 (frame 205/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 144.6ms
# video 1/1 (frame 206/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 157.7ms
# video 1/1 (frame 207/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 136.9ms
# video 1/1 (frame 208/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 136.6ms
# video 1/1 (frame 209/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 136.1ms
# video 1/1 (frame 210/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 141.4ms
# video 1/1 (frame 211/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 159.4ms
# video 1/1 (frame 212/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 137.8ms
# video 1/1 (frame 213/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 136.9ms
# video 1/1 (frame 214/214) /content/drive/MyDrive/MY WORK/ML/07-Tennis-Analysis-System/input_videos/input_video.mp4: 384x640 6 persons, 137.7ms
# Speed: 4.8ms preprocess, 165.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to /content/runs/detect/track

# %% [markdown]
# > ## Display the output video

# %%
# Input & output paths
save_path = "/content/runs/detect/track/input_video.avi"
compressed_path = "/content/result_compressed.mp4"

# Convert + compress (H.264, web-safe)
os.system(
    f"ffmpeg -y -i {save_path} "
    f"-vcodec libx264 -pix_fmt yuv420p -movflags +faststart "
    f"-crf 23 {compressed_path}"
)
# Out:
# 0

# %%
def display_video(path, width=900, height="auto"):
    video_bytes = open(path, "rb").read()
    encoded = b64encode(video_bytes).decode()

    html = f"""
    <video width="{width}" height="{height}" controls autoplay loop>
        <source src="data:video/mp4;base64,{encoded}" type="video/mp4">
    </video>
    """
    return HTML(html)

display_video("/content/result_compressed.mp4", width=900)
# Out:
#     <video width="900" height="auto" controls autoplay loop>
#         <source src="data:video/mp4;base64,..." type="video/mp4">
#     </video>

# %% [markdown]
# # Tenis Ball Detector

# %%
# !pip install -q roboflow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 25.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 59.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 90.7 MB/s eta 0:00:00

# %%
import shutil
from roboflow import Roboflow

# %%
rf = Roboflow(api_key="8joVH7TL2k5V6uScFBEy")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")

# %%
shutil.move("tennis-ball-detection-6/train",
"tennis-ball-detection-6/tennis-ball-detection-6/train",
)
shutil.move("tennis-ball-detection-6/test",
"tennis-ball-detection-6/tennis-ball-detection-6/test",
)
shutil.move("tennis-ball-detection-6/valid",
"tennis-ball-detection-6/tennis-ball-detection-6/valid",
)

# %%
# !yolo task=detect mode=train model=yolov5l6u.pt data={dataset.location}/data.yaml epochs=100 imgsz=640

# %% [markdown]
# # KeyPoints Detector

# %%
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import models, transforms
import json
import cv2
import numpy as np

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# > download and unzip dataset

# %%
# !gdown "https://drive.google.com/uc?id=1O4-mRTgHK4AntMNDdQmOP-jnxXs9agnQ&confirm=t"

# %%
# !unzip "tennis_court_det_dataset.zip"

# %%
class KeypointsDataset(Dataset):
    def __init__(self, img_dir, data_file):
        self.img_dir = img_dir
        with open(data_file, "r") as f:
            self.data = json.load(f)

        self.transforms = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        item = self.data[idx]
        img = cv2.imread(f"{self.img_dir}/{item['id']}.png")
        h,w = img.shape[:2]

        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = self.transforms(img)
        kps = np.array(item['kps']).flatten()
        kps = kps.astype(np.float32)

        kps[::2] *= 224.0 / w # Adjust x coordinates
        kps[1::2] *= 224.0 / h # Adjust y coordinates

        return img, kps

# %%
train_dataset = KeypointsDataset("data/images", "data/data_train.json")
val_dataset = KeypointsDataset("data/images", "data/data_val.json")

train_loader = DataLoader(train_dataset, batch_size = 8, shuffle = True)
val_loader = DataLoader(val_dataset, batch_size = 8, shuffle = True)

# %% [markdown]
# > Create Model

# %%
model = models.resnet50(pretrained = True)
model.fc = torch.nn.Linear(model.fc.in_features, 14 * 2)

# %% [markdown]
# > Move model to device

# %%
model = model.to(device)

# %% [markdown]
# > Train Model

# %%
criterion = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 1e-4)

# %%
epochs=50
for epoch in range(epochs):
    for i, (imgs,kps) in enumerate(train_loader):
        imgs = imgs.to(device)
        kps = kps.to(device)

        optimizer.zero_grad()
        outputs = model(imgs)
        loss = criterion(outputs, kps)
        loss.backward()
        optimizer.step()

        if i % 10 == 0:
            print(f"Epoch {epoch}, iter {i}, loss: {loss.item()}")

# %%
torch.save(model.state_dict(), "keypoints_model_50.pth")

# %% [markdown]
# # Utils

# %%
def get_center_bbox(bbox):
    x1, y1, x2, y2 = bbox
    center_x = int((x1 + x2)/2)
    center_y = int((y1 + y2)/2)
    return (center_x, center_y)

def measure_distance(p1, p2):
    return ((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)**0.5

def read_video(video_path):
    cap = cv2.VideoCapture(video_path)
    frames = []
    while True:
        ret, frame = cap.read()
        if ret:
            frames.append(frame)
        else:
            break
    cap.release()
    return frames

def save_video(output_video_frames, output_video_path):
    fourcc = cv2.VideoWriter_fourcc(*'MJPG')
    out=cv2.VideoWriter(output_video_path, fourcc, 24, (output_video_frames[0].shape[1], output_video_frames[0].shape[0]))
    for frame in output_video_frames:
        out.write(frame)
    out.release()

# %% [markdown]
# # CourtLine Detector

# %%
class CourtLineDetector:
    def __init__(self, model_path):
        self.model = models.resnet50(pretrained = True)
        self.model.fc = torch.nn.Linear(self.model.fc.in_features, 14*2)
        self.model.load_state_dict(torch.load(model_path, map_location = "cpu"))
        self.transform = transforms.Compose([
            transforms.ToPILImage(),
            transforms.Resize((224,224)),
            transforms.ToTensor(),
            transforms.Normalize(mean = [0.485, 0.456, 0.406], std = [0.229, 0.224, 0.225])
        ])

    def predict(self, image):
        image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        image_tensor = self.transform(image_rgb).unsqueeze(0)
        with torch.no_grad():
            outputs = self.model(image_tensor)
        keypoints = outputs.squeeze().cpu().numpy()
        original_height, original_width = image.shape[:2]
        keypoints[::2] *= original_width / 224.0
        keypoints[1::2] *= original_height / 224.0
        return keypoints

    #Plot Keypoints on the image
    def draw_keypoints(self, image, keypoints):
        for i in range(0, len(keypoints), 2):
            x = int(keypoints[i])
            y = int(keypoints[i + 1])
            cv2.putText(image, str(i//2), (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0,0,255), 2)
            cv2.circle(image, (x,y), 5, (0,0,255), -1)
        return image

    #Plot/ Draw keypoints on the video
    def draw_keypoints_on_video(self, video_frames, keypoints):
        output_video_frames = []
        for frame in video_frames:
            frame = self.draw_keypoints(frame, keypoints)
            output_video_frames.append(frame)
        return output_video_frames

# %% [markdown]
# # Player Tracker

# %%
class PlayerTracker:
    def __init__(self, model_path):
        self.model = YOLO(model_path)
    def choose_and_filter_players(self, court_keypoints, player_detections):
        player_detections_first_frame = player_detections[0]
        chosen_player = self.choose_players(court_keypoints, player_detections_first_frame)
        filtered_player_detections = []
        for player_det in player_detections:
            filtered_player_dict = {track_id : bbox for track_id, bbox in player_det.items() if track_id in chosen_player}
            filtered_player_detections.append(filtered_player_dict)
        return filtered_player_detections

    def choose_players(self, court_keypoints, player_dict):
        distances = []
        for track_id, bbox in player_dict.items():
            player_center = get_center_bbox(bbox)
            min_distance = float('inf')
            for i in range(0, len(court_keypoints), 2):
                court_keypoint = (court_keypoints[i], court_keypoints[i + 1])
                distance = measure_distance(player_center, court_keypoint)
                if distance < min_distance:
                    min_distance = distance
            distances.append((track_id, min_distance))
        #Sort the distances in ascending order
        distances.sort(key = lambda x: x[1])
        #Choose the first two tracks
        chosen_players = [distances[0][0], distances[1][0]]
        return chosen_players

    def detect_frame(self, frame):
        results = self.model.track(frame, persist=True)[0]
        class_names = results.names
        player_dict = {}
        for box in results.boxes:
            track_id = int(box.id.tolist()[0])
            result = box.xyxy.tolist()[0]
            class_ids = box.cls.tolist()[0]
            det_class_names = class_names[class_ids]
            if det_class_names == "person":
                player_dict[track_id] = result
        return player_dict
    def detect_frames(self, frames, read_from_stub=False, stub_path=None):
        player_detections = []
        if read_from_stub and stub_path is not None:
            with open(stub_path, 'rb') as f:
                player_detections = pickle.load(f)
                return player_detections
        for frame in frames:
            player_dict = self.detect_frame(frame)
            player_detections.append(player_dict)
        if stub_path is not None:
            with open(stub_path, 'wb') as f:
                pickle.dump(player_detections, f)
        return player_detections
    def draw_bboxes(self, video_frames, player_detections):
        output_video_frames = []
        for frame, player_dict in zip(video_frames, player_detections):
            for track_id, bbox in player_dict.items():
                x1, y1, x2, y2 = bbox
                cv2.putText(frame, f"Player ID: {track_id}", (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,255), 2)
                cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0,0,255), 2)
            output_video_frames.append(frame)
        return output_video_frames

# %% [markdown]
# # Ball Tracker

# %%
class BallTracker:
    def __init__(self, model_path):
        self.model = YOLO(model_path)
    def detect_frame(self, frame):
        results = self.model.predict(frame, conf=0.15)[0]
        ball_dict = {}
        for box in results.boxes:
            result = box.xyxy.tolist()[0]
            ball_dict[1] = result
        return ball_dict
    def detect_frames(self, frames, read_from_stub=False, stub_path=None):
        ball_detections = []
        if read_from_stub and stub_path is not None:
            with open(stub_path, 'rb') as f:
                ball_detections = pickle.load(f)
                return ball_detections
        for frame in frames:
            ball_dict = self.detect_frame(frame)
            ball_detections.append(ball_dict)
        if stub_path is not None:
            with open(stub_path, 'wb') as f:
                pickle.dump(ball_detections, f)
        return ball_detections
    def draw_bboxes(self, video_frames, ball_detections):
        output_video_frames = []
        for frame, ball_dict in zip(video_frames, ball_detections):
            for track_id, bbox in ball_dict.items():
                x1, y1, x2, y2 = bbox
                cv2.putText(frame, f"Ball ID: {track_id}", (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,255,255), 2)
                cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0,255,255), 2)
            output_video_frames.append(frame)
        return output_video_frames

# %% [markdown]
# # Pipeline

# %%
def main():
    #Read the Input Video
    input_video_path = "input_videos/input_video.mp4"
    video_frames = read_video(input_video_path)

    #Detect and Track Players
    player_tracker = PlayerTracker(model_path = "yolo12n.pt")
    player_detections = player_tracker.detect_frames(video_frames, read_from_stub=True, stub_path="tracker_stubs/player_detection.pkl")

    #Detect Tennis Ball
    ball_tracker = BallTracker(model_path = "models/tennis_ball_best.pt")
    ball_detections = ball_tracker.detect_frames(video_frames, read_from_stub=True, stub_path="tracker_stubs/ball_detection.pkl")

    #Detect Tennis Court Keypoints
    court_model_path = "models/keypoints_model_50.pth"
    court_line_detector = CourtLineDetector(court_model_path)
    court_keypoints = court_line_detector.predict(video_frames[0])

    #Choose & Filter Players
    player_detections = player_tracker.choose_and_filter_players(court_keypoints, player_detections)

    #Draw Output
    #Draw Player Bounding Boxes
    output_video_frames = player_tracker.draw_bboxes(video_frames, player_detections)
    #Draw Tennis Ball Bounding Boxes
    output_video_frames = ball_tracker.draw_bboxes(output_video_frames, ball_detections)
    #Draw Tennis Court Keypoints
    output_video_frames = court_line_detector.draw_keypoints_on_video(output_video_frames, court_keypoints)

    #Save Video
    save_video(output_video_frames, "output_videos/output.avi")
